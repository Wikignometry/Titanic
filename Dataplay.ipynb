# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
titanic_df = pd.read_csv('tt-train.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
ax=titanic_df.hist(column='Age', bins=80)
ax[0][0].xaxis.set_ticks(range(0,81,5))
# Out:
# [<matplotlib.axis.XTick at 0x7f7f69d3c790>,
#  <matplotlib.axis.XTick at 0x7f7f69d31dd0>,
#  <matplotlib.axis.XTick at 0x7f7f6a376610>,
#  <matplotlib.axis.XTick at 0x7f7f69d57d50>,
#  <matplotlib.axis.XTick at 0x7f7f6a61b390>,
#  <matplotlib.axis.XTick at 0x7f7f6a61b890>,
#  <matplotlib.axis.XTick at 0x7f7f6a61be50>,
#  <matplotlib.axis.XTick at 0x7f7f6a620410>,
#  <matplotlib.axis.XTick at 0x7f7f6a620990>,
#  <matplotlib.axis.XTick at 0x7f7f6a620f10>,
#  <matplotlib.axis.XTick at 0x7f7f6a626490>,
#  <matplotlib.axis.XTick at 0x7f7f6a626a10>,
#  <matplotlib.axis.XTick at 0x7f7f6a626910>,
#  <matplotlib.axis.XTick at 0x7f7f6a6261d0>,
#  <matplotlib.axis.XTick at 0x7f7f6a620390>,
#  <matplotlib.axis.XTick at 0x7f7f6a4ad1d0>,
#  <matplotlib.axis.XTick at 0x7f7f6a62e790>]

# %%
bx=titanic_df['Age'][titanic_df.Survived==1].hist(bins=80)
bx.yaxis.set_ticks(range(0,30,5))
# Out:
# [<matplotlib.axis.YTick at 0x7f7f6588c150>,
#  <matplotlib.axis.YTick at 0x7f7f6aa2b790>,
#  <matplotlib.axis.YTick at 0x7f7f6aa12ed0>,
#  <matplotlib.axis.YTick at 0x7f7f6aa45710>,
#  <matplotlib.axis.YTick at 0x7f7f6aba4a10>,
#  <matplotlib.axis.YTick at 0x7f7f6aba4910>]

# %%
ax=titanic_df.plot.line(x='Age',y='Survived')
ax[0][0].xaxis.set_ticks(range(0,81,5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-794e560154fb> in <module>
#       1 ax=titanic_df.plot.line(x='Age',y='Survived')
# ----> 2 ax[0][0].xaxis.set_ticks(range(0,81,5))
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
titanic_df['Age'][titanic_df.Survived == 1].plot.kde( color='blue')
titanic_df['Age'][titanic_df.Survived == 0].plot.kde( color='red')

# %%
ax=sns.lineplot(x='Age',y='Survived', data=titanic_df)
ax.xaxis.set_ticks(range(0,81,5))
# Out:
# [<matplotlib.axis.XTick at 0x7f7f66258490>,
#  <matplotlib.axis.XTick at 0x7f7f662663d0>,
#  <matplotlib.axis.XTick at 0x7f7f6a358350>,
#  <matplotlib.axis.XTick at 0x7f7f6a5a57d0>,
#  <matplotlib.axis.XTick at 0x7f7f662996d0>,
#  <matplotlib.axis.XTick at 0x7f7f66299650>,
#  <matplotlib.axis.XTick at 0x7f7f6a5b5350>,
#  <matplotlib.axis.XTick at 0x7f7f6a5b5d90>,
#  <matplotlib.axis.XTick at 0x7f7f6a5a3390>,
#  <matplotlib.axis.XTick at 0x7f7f6a5a3910>,
#  <matplotlib.axis.XTick at 0x7f7f6a5a3e50>,
#  <matplotlib.axis.XTick at 0x7f7f662668d0>,
#  <matplotlib.axis.XTick at 0x7f7f6625fd10>,
#  <matplotlib.axis.XTick at 0x7f7f6a5c1b90>,
#  <matplotlib.axis.XTick at 0x7f7f6a5c80d0>,
#  <matplotlib.axis.XTick at 0x7f7f6a5c8710>,
#  <matplotlib.axis.XTick at 0x7f7f6a5c8c90>]

# %%
ax=sns.barplot(x='Age',y='Survived', data=titanic_df, ci=None)
# ax.xaxis.set_ticks(range(0,81,5))

# %%
ax=sns.barplot(x='Age',y='Survived', data=titanic_df, ci=None)
print(ax)
ax.xaxis.set_ticks(range(0,81,5))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# [<matplotlib.axis.XTick at 0x7f7f6b908210>,
#  <matplotlib.axis.XTick at 0x7f7f6b903910>,
#  <matplotlib.axis.XTick at 0x7f7f6b903650>,
#  <matplotlib.axis.XTick at 0x7f7f6bb49a50>,
#  <matplotlib.axis.XTick at 0x7f7f6bb49f10>,
#  <matplotlib.axis.XTick at 0x7f7f6bb515d0>,
#  <matplotlib.axis.XTick at 0x7f7f6bb51c90>,
#  <matplotlib.axis.XTick at 0x7f7f6bb51e10>,
#  <matplotlib.axis.XTick at 0x7f7f6bb5a490>,
#  <matplotlib.axis.XTick at 0x7f7f6bb5aad0>,
#  <matplotlib.axis.XTick at 0x7f7f6bb61050>,
#  <matplotlib.axis.XTick at 0x7f7f6bb61750>,
#  <matplotlib.axis.XTick at 0x7f7f6bb61d90>,
#  <matplotlib.axis.XTick at 0x7f7f6bb67410>,
#  <matplotlib.axis.XTick at 0x7f7f6bb67a50>,
#  <matplotlib.axis.XTick at 0x7f7f6bb67d90>,
#  <matplotlib.axis.XTick at 0x7f7f6bb61290>]

# %%
titanic_df['Round_Age']=np.floor(titanic_df['Age'])
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Round_Age
# 0      0         A/5 21171   7.2500   NaN        S       22.0
# 1      0          PC 17599  71.2833   C85        C       38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0
# 3      0            113803  53.1000  C123        S       35.0
# 4      0            373450   8.0500   NaN        S       35.0

# %%
ax=sns.barplot(x='Round_Age',y='Survived', data=titanic_df, ci=None)
print(ax)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
titanic_df['Family']=titanic_df['SibSp'] + titanic_df['Parch']
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Round_Age  Family
# 0      0         A/5 21171   7.2500   NaN        S       22.0       1
# 1      0          PC 17599  71.2833   C85        C       38.0       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0       0
# 3      0            113803  53.1000  C123        S       35.0       1
# 4      0            373450   8.0500   NaN        S       35.0       0

# %%
sns.barplot(x='Family', y='Survived', data=titanic_df)

# %%
sns.barplot(x='SibSp', y='Survived', data=titanic_df)

# %%
sns.barplot(x='Parch', y='Survived', data=titanic_df)

# %%
titanic_df['Cabin'].str.replace('F ',"")
titanic_df['Zone']=titanic_df['Cabin'].str.get(0)

# %%
sns.barplot(x='Zone', y='Survived', data=titanic_df)

# %%
sns.barplot(x='Zone', y='Pclass', data=titanic_df)

# %%
sns.barplot(x='Pclass', y='Survived', data=titanic_df)

# %%
ax=titanic_df.plot.scatter(x='Age', y='Fare', color='Blue')

# %%
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=titanic_df)

# %%
sns.barplot(x='Pclass', y='Survived', data=titanic_df[titanic_df.Zone == 'A'])
